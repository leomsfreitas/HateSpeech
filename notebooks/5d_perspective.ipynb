# %% [markdown]
# # Environment

# %%
import os
os.chdir("..")

# %%
import pandas as pd
from sklearn.metrics import classification_report

from src.pipeline.perspective import PipelinePerspective, PerspectiveConfig
from src.utils.path import DATA_PATH

# %%
API_KEY = os.environ.get("PERSPECTIVE_API_KEY")

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv(f"{DATA_PATH}/ited-br/processed/ited-br.csv").sample(1)

# %% [markdown]
# # Binary Classification

# %%
config = PerspectiveConfig(
    api_key=API_KEY,
    label_column="offensive",
    threshold=0.4,
)

# %%
pipeline = PipelinePerspective(config)
y_pred = pipeline.predict(df, "text")
y_true = df["offensive"]
print(classification_report(y_true, y_pred))
